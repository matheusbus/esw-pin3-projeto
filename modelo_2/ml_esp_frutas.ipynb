# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, GlobalAveragePooling2D
from tensorflow.keras.losses import CategoricalCrossentropy
import random
from sklearn.model_selection import train_test_split
import shutil

# %%
## 1.0. Rebalanceamento
def undersample(src_dir, target_dir, target_count):
    src_len = len(os.listdir(src_dir))
    
    if not os.path.exists(target_dir):
        target_dir = os.path.join("imagens", target_dir)
        os.makedirs(target_dir)
    
    images = os.listdir(src_dir)
    
    selected_images = random.sample(images, target_count)
    
    for img in images:
        if img in selected_images:
            img_src_path = os.path.join(src_dir, img)
            img_target_path = os.path.join(target_dir, img)
            shutil.copy(img_src_path, img_target_path)
            print(f'Imagem movida: {img}')
    
    print(f'Undersampling concluído para a pasta {src_dir}.')

dataset_dir = os.path.join(os.getcwd(), 'imagens')
dataset_morango_dir = os.path.join(dataset_dir, 'morango')
dataset_pessego_dir = os.path.join(dataset_dir, 'pessego')
dataset_roma_dir = os.path.join(dataset_dir, 'roma')

# Define o número alvo de imagens para cada categoria (o menor número de imagens entre todas as categorias)
target_count = min(len(os.listdir(dataset_morango_dir)), len(os.listdir(dataset_pessego_dir)), len(os.listdir(dataset_roma_dir)))

# Aplicar undersampling a cada categoria
undersample(dataset_morango_dir, "morango_rebalanceado", target_count)
undersample(dataset_pessego_dir, "pessego_rebalanceado", target_count)
undersample(dataset_roma_dir, "roma_rebalanceado", target_count)

# 1.1. Dataset das imagens
dataset_dir = os.path.join(os.getcwd(), 'imagens')
dataset_morango_dir = os.path.join(dataset_dir, 'morango_rebalanceado')
dataset_pessego_dir = os.path.join(dataset_dir, 'pessego_rebalanceado')
dataset_roma_dir = os.path.join(dataset_dir, 'roma_rebalanceado')

dataset_morango_len = len(os.listdir(dataset_morango_dir))
dataset_pessego_len = len(os.listdir(dataset_pessego_dir))
dataset_roma_len = len(os.listdir(dataset_roma_dir))

print(f'Contagem de imagens de morango rebalanceado: {dataset_morango_len}')
print(f'Contagem de imagens de pêssego rebalanceado: {dataset_pessego_len}')
print(f'Contagem de imagens de romã rebalanceado: {dataset_roma_len}')
# Out:
# Imagem movida: ms_1.jpg
# Imagem movida: ms_10.jpg
# Imagem movida: ms_100.jpg
# Imagem movida: ms_101.jpg
# Imagem movida: ms_102.jpg
# Imagem movida: ms_103.jpg
# Imagem movida: ms_104.jpg
# Imagem movida: ms_105.jpg
# Imagem movida: ms_106.jpg
# Imagem movida: ms_107.jpg
# Imagem movida: ms_108.jpg
# Imagem movida: ms_109.jpg
# Imagem movida: ms_11.jpg
# Imagem movida: ms_110.jpg
# Imagem movida: ms_111.jpg
# Imagem movida: ms_112.jpg
# Imagem movida: ms_113.jpg
# Imagem movida: ms_114.jpg
# Imagem movida: ms_115.jpg
# Imagem movida: ms_116.jpg
# Imagem movida: ms_117.jpg
# Imagem movida: ms_118.jpg
# Imagem movida: ms_119.jpg
# Imagem movida: ms_12.jpg
# Imagem movida: ms_120.jpg
# Imagem movida: ms_121.jpg
# Imagem movida: ms_122.jpg
# Imagem movida: ms_123.jpg
# Imagem movida: ms_124.jpg
# Imagem movida: ms_125.jpg
# Imagem movida: ms_126.jpg
# Imagem movida: ms_127.jpg
# Imagem movida: ms_128.jpg
# Imagem movida: ms_129.jpg
# Imagem movida: ms_13.jpg
# Imagem movida: ms_130.jpg
# Imagem movida: ms_131.jpg
# Imagem movida: ms_132.jpg
# Imagem movida: ms_133.jpg
# Imagem movida: ms_134.jpg
# Imagem movida: ms_135.jpg
# Imagem movida: ms_136.jpg
# Imagem movida: ms_137.jpg
# Imagem movida: ms_138.jpg
# Imagem movida: ms_139.jpg
# Imagem movida: ms_14.jpg
# Imagem movida: ms_140.jpg
# Imagem movida: ms_141.jpg
# Imagem movida: ms_142.jpg
# Imagem movida: ms_143.jpg
# Imagem movida: ms_144.jpg
# Imagem movida: ms_145.jpg
# Imagem movida: ms_146.jpg
# Imagem movida: ms_147.jpg
# Imagem movida: ms_148.jpg
# Imagem movida: ms_149.jpg
# Imagem movida: ms_15.jpg
# Imagem movida: ms_150.jpg
# Imagem movida: ms_151.jpg
# Imagem movida: ms_152.jpg
# Imagem movida: ms_153.jpg
# Imagem movida: ms_154.jpg
# Imagem movida: ms_155.jpg
# Imagem movida: ms_156.jpg
# Imagem movida: ms_157.jpg
# Imagem movida: ms_158.jpg
# Imagem movida: ms_159.jpg
# Imagem movida: ms_16.jpg
# Imagem movida: ms_160.jpg
# Imagem movida: ms_161.jpg
# Imagem movida: ms_162.jpg
# Imagem movida: ms_163.jpg
# Imagem movida: ms_164.jpg
# Imagem movida: ms_165.jpg
# Imagem movida: ms_166.jpg
# Imagem movida: ms_167.jpg
# Imagem movida: ms_168.jpg
# Imagem movida: ms_169.jpg
# Imagem movida: ms_17.jpg
# Imagem movida: ms_170.jpg
# Imagem movida: ms_171.jpg
# Imagem movida: ms_172.jpg
# Imagem movida: ms_173.jpg
# Imagem movida: ms_174.jpg
# Imagem movida: ms_175.jpg
# Imagem movida: ms_176.jpg
# Imagem movida: ms_177.jpg
# Imagem movida: ms_178.jpg
# Imagem movida: ms_179.jpg
# Imagem movida: ms_18.jpg
# Imagem movida: ms_180.jpg
# Imagem movida: ms_181.jpg
# Imagem movida: ms_182.jpg
# Imagem movida: ms_183.jpg
# Imagem movida: ms_184.jpg
# Imagem movida: ms_185.jpg
# Imagem movida: ms_186.jpg
# Imagem movida: ms_187.jpg
# Imagem movida: ms_188.jpg
# Imagem movida: ms_189.jpg
# Imagem movida: ms_19.jpg
# Imagem movida: ms_190.jpg
# Imagem movida: ms_191.jpg
# Imagem movida: ms_192.jpg
# Imagem movida: ms_193.jpg
# Imagem movida: ms_194.jpg
# Imagem movida: ms_195.jpg
# Imagem movida: ms_196.jpg
# Imagem movida: ms_197.jpg
# Imagem movida: ms_198.jpg
# Imagem movida: ms_199.jpg
# Imagem movida: ms_2.jpg
# Imagem movida: ms_20.jpg
# Imagem movida: ms_200.jpg
# Imagem movida: ms_201.jpg
# Imagem movida: ms_202.jpg
# Imagem movida: ms_203.jpg
# Imagem movida: ms_204.jpg
# Imagem movida: ms_205.jpg
# Imagem movida: ms_206.jpg
# Imagem movida: ms_207.jpg
# Imagem movida: ms_208.jpg
# Imagem movida: ms_209.jpg
# Imagem movida: ms_21.jpg
# Imagem movida: ms_210.jpg
# Imagem movida: ms_211.jpg
# Imagem movida: ms_212.jpg
# Imagem movida: ms_213.jpg
# Imagem movida: ms_214.jpg
# Imagem movida: ms_215.jpg
# Imagem movida: ms_216.jpg
# Imagem movida: ms_217.jpg
# Imagem movida: ms_218.jpg
# Imagem movida: ms_219.jpg
# Imagem movida: ms_22.jpg
# Imagem movida: ms_220.jpg
# Imagem movida: ms_221.jpg
# Imagem movida: ms_222.jpg
# Imagem movida: ms_223.jpg
# Imagem movida: ms_224.jpg
# Imagem movida: ms_225.jpg
# Imagem movida: ms_226.jpg
# Imagem movida: ms_227.jpg
# Imagem movida: ms_228.jpg
# Imagem movida: ms_229.jpg
# Imagem movida: ms_23.jpg
# Imagem movida: ms_230.jpg
# Imagem movida: ms_231.jpg
# Imagem movida: ms_232.jpg
# Imagem movida: ms_233.jpg
# Imagem movida: ms_234.jpg
# Imagem movida: ms_235.jpg
# Imagem movida: ms_236.jpg
# Imagem movida: ms_237.jpg
# Imagem movida: ms_238.jpg
# Imagem movida: ms_239.jpg
# Imagem movida: ms_24.jpg
# Imagem movida: ms_240.jpg
# Imagem movida: ms_241.jpg
# Imagem movida: ms_242.jpg
# Imagem movida: ms_243.jpg
# Imagem movida: ms_244.jpg
# Imagem movida: ms_245.jpg
# Imagem movida: ms_246.jpg
# Imagem movida: ms_247.jpg
# Imagem movida: ms_248.jpg
# Imagem movida: ms_249.jpg
# Imagem movida: ms_25.jpg
# Imagem movida: ms_250.jpg
# Imagem movida: ms_251.jpg
# Imagem movida: ms_252.jpg
# Imagem movida: ms_253.jpg
# Imagem movida: ms_254.jpg
# Imagem movida: ms_26.jpg
# Imagem movida: ms_27.jpg
# Imagem movida: ms_28.jpg
# Imagem movida: ms_29.jpg
# Imagem movida: ms_3.jpg
# Imagem movida: ms_30.jpg
# Imagem movida: ms_31.jpg
# Imagem movida: ms_32.jpg
# Imagem movida: ms_33.jpg
# Imagem movida: ms_34.jpg
# Imagem movida: ms_35.jpg
# Imagem movida: ms_36.jpg
# Imagem movida: ms_37.jpg
# Imagem movida: ms_38.jpg
# Imagem movida: ms_39.jpg
# Imagem movida: ms_4.jpg
# Imagem movida: ms_40.jpg
# Imagem movida: ms_41.jpg
# Imagem movida: ms_42.jpg
# Imagem movida: ms_43.jpg
# Imagem movida: ms_44.jpg
# Imagem movida: ms_45.jpg
# Imagem movida: ms_46.jpg
# Imagem movida: ms_47.jpg
# Imagem movida: ms_48.jpg
# Imagem movida: ms_49.jpg
# Imagem movida: ms_5.jpg
# Imagem movida: ms_50.jpg
# Imagem movida: ms_51.jpg
# Imagem movida: ms_52.jpg
# Imagem movida: ms_53.jpg
# Imagem movida: ms_54.jpg
# Imagem movida: ms_55.jpg
# Imagem movida: ms_56.jpg
# Imagem movida: ms_57.jpg
# Imagem movida: ms_58.jpg
# Imagem movida: ms_59.jpg
# Imagem movida: ms_6.jpg
# Imagem movida: ms_60.jpg
# Imagem movida: ms_61.jpg
# Imagem movida: ms_62.jpg
# Imagem movida: ms_63.jpg
# Imagem movida: ms_64.jpg
# Imagem movida: ms_65.jpg
# Imagem movida: ms_66.jpg
# Imagem movida: ms_67.jpg
# Imagem movida: ms_68.jpg
# Imagem movida: ms_69.jpg
# Imagem movida: ms_7.jpg
# Imagem movida: ms_70.jpg
# Imagem movida: ms_71.jpg
# Imagem movida: ms_72.jpg
# Imagem movida: ms_73.jpg
# Imagem movida: ms_74.jpg
# Imagem movida: ms_75.jpg
# Imagem movida: ms_76.jpg
# Imagem movida: ms_77.jpg
# Imagem movida: ms_78.jpg
# Imagem movida: ms_8.jpg
# Imagem movida: ms_83.jpg
# Imagem movida: ms_84.jpg
# Imagem movida: ms_85.jpg
# Imagem movida: ms_86.jpg
# Imagem movida: ms_87.jpg
# Imagem movida: ms_88.jpg
# Imagem movida: ms_89.jpg
# Imagem movida: ms_9.jpg
# Imagem movida: ms_90.jpg
# Imagem movida: ms_91.jpg
# Imagem movida: ms_92.jpg
# Imagem movida: ms_93.jpg
# Imagem movida: ms_94.jpg
# Imagem movida: ms_95.jpg
# Imagem movida: ms_96.jpg
# Imagem movida: ms_97.jpg
# Imagem movida: ms_98.jpg
# Imagem movida: ms_99.jpg
# Undersampling concluído para a pasta c:\Users\rdalm\OneDrive\Área de Trabalho\esw-pin3-projeto\esw-pin3-projeto\modelo_2\imagens\morango.
# Imagem movida: ps_1.jpg
# Imagem movida: ps_10.jpg
# Imagem movida: ps_100.jpg
# Imagem movida: ps_101.jpg
# Imagem movida: ps_102.jpg
# Imagem movida: ps_103.jpg
# Imagem movida: ps_104.jpg
# Imagem movida: ps_105.jpg
# Imagem movida: ps_106.jpg
# Imagem movida: ps_107.jpg
# Imagem movida: ps_108.jpg
# Imagem movida: ps_109.jpg
# Imagem movida: ps_11.jpg
# Imagem movida: ps_110.jpg
# Imagem movida: ps_111.jpg
# Imagem movida: ps_112.jpg
# Imagem movida: ps_113.jpg
# Imagem movida: ps_114.jpg
# Imagem movida: ps_115.jpg
# Imagem movida: ps_116.jpg
# Imagem movida: ps_117.jpg
# Imagem movida: ps_118.jpg
# Imagem movida: ps_119.jpg
# Imagem movida: ps_12.jpg
# Imagem movida: ps_120.jpg
# Imagem movida: ps_121.jpg
# Imagem movida: ps_122.jpg
# Imagem movida: ps_123.jpg
# Imagem movida: ps_124.jpg
# Imagem movida: ps_125.jpg
# Imagem movida: ps_126.jpg
# Imagem movida: ps_127.jpg
# Imagem movida: ps_128.jpg
# Imagem movida: ps_129.jpg
# Imagem movida: ps_13.jpg
# Imagem movida: ps_130.jpg
# Imagem movida: ps_131.jpg
# Imagem movida: ps_132.jpg
# Imagem movida: ps_133.jpg
# Imagem movida: ps_134.jpg
# Imagem movida: ps_135.jpg
# Imagem movida: ps_136.jpg
# Imagem movida: ps_137.jpg
# Imagem movida: ps_139.jpg
# Imagem movida: ps_14.jpg
# Imagem movida: ps_140.jpg
# Imagem movida: ps_141.jpg
# Imagem movida: ps_142.jpg
# Imagem movida: ps_143.jpg
# Imagem movida: ps_144.jpg
# Imagem movida: ps_145.jpg
# Imagem movida: ps_146.jpg
# Imagem movida: ps_147.jpg
# Imagem movida: ps_148.jpg
# Imagem movida: ps_149.jpg
# Imagem movida: ps_15.jpg
# Imagem movida: ps_150.jpg
# Imagem movida: ps_151.jpg
# Imagem movida: ps_152.jpg
# Imagem movida: ps_153.jpg
# Imagem movida: ps_154.jpg
# Imagem movida: ps_155.jpg
# Imagem movida: ps_156.jpg
# Imagem movida: ps_157.jpg
# Imagem movida: ps_158.jpg
# Imagem movida: ps_159.jpg
# Imagem movida: ps_16.jpg
# Imagem movida: ps_160.jpg
# Imagem movida: ps_161.jpg
# Imagem movida: ps_162.jpg
# Imagem movida: ps_163.jpg
# Imagem movida: ps_164.jpg
# Imagem movida: ps_165.jpg
# Imagem movida: ps_166.jpg
# Imagem movida: ps_167.jpg
# Imagem movida: ps_168.jpg
# Imagem movida: ps_169.jpg
# Imagem movida: ps_17.jpg
# Imagem movida: ps_170.jpg
# Imagem movida: ps_171.jpg
# Imagem movida: ps_172.jpg
# Imagem movida: ps_173.jpg
# Imagem movida: ps_174.jpg
# Imagem movida: ps_175.jpg
# Imagem movida: ps_176.jpg
# Imagem movida: ps_177.jpg
# Imagem movida: ps_178.jpg
# Imagem movida: ps_179.jpg
# Imagem movida: ps_18.jpg
# Imagem movida: ps_180.jpg
# Imagem movida: ps_181.jpg
# Imagem movida: ps_182.jpg
# Imagem movida: ps_183.jpg
# Imagem movida: ps_188.jpg
# Imagem movida: ps_189.jpg
# Imagem movida: ps_190.jpg
# Imagem movida: ps_192.jpg
# Imagem movida: ps_196.jpg
# Imagem movida: ps_198.jpg
# Imagem movida: ps_199.jpg
# Imagem movida: ps_20.jpg
# Imagem movida: ps_201.jpg
# Imagem movida: ps_202.jpg
# Imagem movida: ps_203.jpg
# Imagem movida: ps_204.jpg
# Imagem movida: ps_205.jpg
# Imagem movida: ps_206.jpg
# Imagem movida: ps_209.jpg
# Imagem movida: ps_21.jpg
# Imagem movida: ps_210.jpg
# Imagem movida: ps_211.jpg
# Imagem movida: ps_212.jpg
# Imagem movida: ps_213.jpg
# Imagem movida: ps_214.jpg
# Imagem movida: ps_215.jpg
# Imagem movida: ps_216.jpg
# Imagem movida: ps_217.jpg
# Imagem movida: ps_218.jpg
# Imagem movida: ps_219.jpg
# Imagem movida: ps_22.jpg
# Imagem movida: ps_220.jpg
# Imagem movida: ps_221.jpg
# Imagem movida: ps_222.jpg
# Imagem movida: ps_223.jpg
# Imagem movida: ps_224.jpg
# Imagem movida: ps_225.jpg
# Imagem movida: ps_226.jpg
# Imagem movida: ps_227.jpg
# Imagem movida: ps_228.jpg
# Imagem movida: ps_229.jpg
# Imagem movida: ps_23.jpg
# Imagem movida: ps_230.jpg
# Imagem movida: ps_231.jpg
# Imagem movida: ps_232.jpg
# Imagem movida: ps_233.jpg
# Imagem movida: ps_234.jpg
# Imagem movida: ps_235.jpg
# Imagem movida: ps_236.jpg
# Imagem movida: ps_237.jpg
# Imagem movida: ps_238.jpg
# Imagem movida: ps_239.jpg
# Imagem movida: ps_24.jpg
# Imagem movida: ps_241.jpg
# Imagem movida: ps_242.jpg
# Imagem movida: ps_243.jpg
# Imagem movida: ps_244.jpg
# Imagem movida: ps_245.jpg
# Imagem movida: ps_246.jpg
# Imagem movida: ps_247.jpg
# Imagem movida: ps_248.jpg
# Imagem movida: ps_249.jpg
# Imagem movida: ps_25.jpg
# Imagem movida: ps_250.jpg
# Imagem movida: ps_251.jpg
# Imagem movida: ps_252.jpg
# Imagem movida: ps_253.jpg
# Imagem movida: ps_254.jpg
# Imagem movida: ps_255.jpg
# Imagem movida: ps_256.jpg
# Imagem movida: ps_257.jpg
# Imagem movida: ps_258.jpg
# Imagem movida: ps_259.jpg
# Imagem movida: ps_26.jpg
# Imagem movida: ps_260.jpg
# Imagem movida: ps_261.jpg
# Imagem movida: ps_262.jpg
# Imagem movida: ps_263.jpg
# Imagem movida: ps_264.jpg
# Imagem movida: ps_265.jpg
# Imagem movida: ps_266.jpg
# Imagem movida: ps_267.jpg
# Imagem movida: ps_268.jpg
# Imagem movida: ps_269.jpg
# Imagem movida: ps_27.jpg
# Imagem movida: ps_270.jpg
# Imagem movida: ps_271.jpg
# Imagem movida: ps_273.jpg
# Imagem movida: ps_28.jpg
# Imagem movida: ps_29.jpg
# Imagem movida: ps_3.jpg
# Imagem movida: ps_30.jpg
# Imagem movida: ps_31.jpg
# Imagem movida: ps_32.jpg
# Imagem movida: ps_33.jpg
# Imagem movida: ps_35.jpg
# Imagem movida: ps_36.jpg
# Imagem movida: ps_37.jpg
# Imagem movida: ps_38.jpg
# Imagem movida: ps_39.jpg
# Imagem movida: ps_4.jpg
# Imagem movida: ps_40.jpg
# Imagem movida: ps_41.jpg
# Imagem movida: ps_42.jpg
# Imagem movida: ps_43.jpg
# Imagem movida: ps_44.jpg
# Imagem movida: ps_45.jpg
# Imagem movida: ps_46.jpg
# Imagem movida: ps_47.jpg
# Imagem movida: ps_48.jpg
# Imagem movida: ps_49.jpg
# Imagem movida: ps_50.jpg
# Imagem movida: ps_51.jpg
# Imagem movida: ps_52.jpg
# Imagem movida: ps_53.jpg
# Imagem movida: ps_54.jpg
# Imagem movida: ps_55.jpg
# Imagem movida: ps_56.jpg
# Imagem movida: ps_57.jpg
# Imagem movida: ps_58.jpg
# Imagem movida: ps_59.jpg
# Imagem movida: ps_6.jpg
# Imagem movida: ps_60.jpg
# Imagem movida: ps_61.jpg
# Imagem movida: ps_62.jpg
# Imagem movida: ps_63.jpg
# Imagem movida: ps_64.jpg
# Imagem movida: ps_65.jpg
# Imagem movida: ps_66.jpg
# Imagem movida: ps_67.jpg
# Imagem movida: ps_68.jpg
# Imagem movida: ps_69.jpg
# Imagem movida: ps_7.jpg
# Imagem movida: ps_70.jpg
# Imagem movida: ps_71.jpg
# Imagem movida: ps_72.jpg
# Imagem movida: ps_73.jpg
# Imagem movida: ps_74.jpg
# Imagem movida: ps_75.jpg
# Imagem movida: ps_76.jpg
# Imagem movida: ps_77.jpg
# Imagem movida: ps_78.jpg
# Imagem movida: ps_79.jpg
# Imagem movida: ps_8.jpg
# Imagem movida: ps_80.jpg
# Imagem movida: ps_81.jpg
# Imagem movida: ps_82.jpg
# Imagem movida: ps_83.jpg
# Imagem movida: ps_84.jpg
# Imagem movida: ps_85.jpg
# Imagem movida: ps_86.jpg
# Imagem movida: ps_87.jpg
# Imagem movida: ps_88.jpg
# Imagem movida: ps_9.jpg
# Imagem movida: ps_91.jpg
# Imagem movida: ps_94.jpg
# Imagem movida: ps_95.jpg
# Imagem movida: ps_96.jpg
# Imagem movida: ps_97.jpg
# Imagem movida: ps_98.jpg
# Imagem movida: ps_99.jpg
# Undersampling concluído para a pasta c:\Users\rdalm\OneDrive\Área de Trabalho\esw-pin3-projeto\esw-pin3-projeto\modelo_2\imagens\pessego.
# Imagem movida: rs_1.jpg
# Imagem movida: rs_101.jpg
# Imagem movida: rs_102.jpg
# Imagem movida: rs_103.jpg
# Imagem movida: rs_104.jpg
# Imagem movida: rs_105.jpg
# Imagem movida: rs_106.jpg
# Imagem movida: rs_107.jpg
# Imagem movida: rs_108.jpg
# Imagem movida: rs_109.jpg
# Imagem movida: rs_11.jpg
# Imagem movida: rs_110.jpg
# Imagem movida: rs_111.jpg
# Imagem movida: rs_112.jpg
# Imagem movida: rs_113.jpg
# Imagem movida: rs_114.jpg
# Imagem movida: rs_115.jpg
# Imagem movida: rs_116.jpg
# Imagem movida: rs_117.jpg
# Imagem movida: rs_118.jpg
# Imagem movida: rs_119.jpg
# Imagem movida: rs_120.jpg
# Imagem movida: rs_122.jpg
# Imagem movida: rs_124.jpg
# Imagem movida: rs_125.jpg
# Imagem movida: rs_126.jpg
# Imagem movida: rs_127.jpg
# Imagem movida: rs_128.jpg
# Imagem movida: rs_13.jpg
# Imagem movida: rs_131.jpg
# Imagem movida: rs_132.jpg
# Imagem movida: rs_133.jpg
# Imagem movida: rs_134.jpg
# Imagem movida: rs_135.jpg
# Imagem movida: rs_137.jpg
# Imagem movida: rs_138.jpg
# Imagem movida: rs_141.jpg
# Imagem movida: rs_142.jpg
# Imagem movida: rs_143.jpg
# Imagem movida: rs_144.jpg
# Imagem movida: rs_147.jpg
# Imagem movida: rs_148.jpg
# Imagem movida: rs_149.jpg
# Imagem movida: rs_15.jpg
# Imagem movida: rs_150.jpg
# Imagem movida: rs_151.jpg
# Imagem movida: rs_152.jpg
# Imagem movida: rs_154.jpg
# Imagem movida: rs_155.jpg
# Imagem movida: rs_156.jpg
# Imagem movida: rs_157.jpg
# Imagem movida: rs_158.jpg
# Imagem movida: rs_159.jpg
# Imagem movida: rs_16.jpg
# Imagem movida: rs_161.jpg
# Imagem movida: rs_162.jpg
# Imagem movida: rs_163.jpg
# Imagem movida: rs_164.jpg
# Imagem movida: rs_165.jpg
# Imagem movida: rs_166.jpg
# Imagem movida: rs_167.jpg
# Imagem movida: rs_168.jpg
# Imagem movida: rs_169.jpg
# Imagem movida: rs_17.jpg
# Imagem movida: rs_170.jpg
# Imagem movida: rs_171.jpg
# Imagem movida: rs_172.jpg
# Imagem movida: rs_173.jpg
# Imagem movida: rs_174.jpg
# Imagem movida: rs_175.jpg
# Imagem movida: rs_177.jpg
# Imagem movida: rs_178.jpg
# Imagem movida: rs_179.jpg
# Imagem movida: rs_18.jpg
# Imagem movida: rs_180.jpg
# Imagem movida: rs_181.jpg
# Imagem movida: rs_182.jpg
# Imagem movida: rs_184.jpg
# Imagem movida: rs_185.jpg
# Imagem movida: rs_186.jpg
# Imagem movida: rs_189.jpg
# Imagem movida: rs_19.jpg
# Imagem movida: rs_190.jpg
# Imagem movida: rs_191.jpg
# Imagem movida: rs_192.jpg
# Imagem movida: rs_193.jpg
# Imagem movida: rs_194.jpg
# Imagem movida: rs_195.jpg
# Imagem movida: rs_196.jpg
# Imagem movida: rs_197.jpg
# Imagem movida: rs_199.jpg
# Imagem movida: rs_20.jpg
# Imagem movida: rs_200.jpg
# Imagem movida: rs_201.jpg
# Imagem movida: rs_203.jpg
# Imagem movida: rs_204.jpg
# Imagem movida: rs_205.jpg
# Imagem movida: rs_206.jpg
# Imagem movida: rs_207.jpg
# Imagem movida: rs_208.jpg
# Imagem movida: rs_209.jpg
# Imagem movida: rs_21.jpg
# Imagem movida: rs_211.jpg
# Imagem movida: rs_213.jpg
# Imagem movida: rs_214.jpg
# Imagem movida: rs_215.jpg
# Imagem movida: rs_217.jpg
# Imagem movida: rs_218.jpg
# Imagem movida: rs_22.jpg
# Imagem movida: rs_220.jpg
# Imagem movida: rs_221.jpg
# Imagem movida: rs_224.jpg
# Imagem movida: rs_225.jpg
# Imagem movida: rs_226.jpg
# Imagem movida: rs_227.jpg
# Imagem movida: rs_228.jpg
# Imagem movida: rs_23.jpg
# Imagem movida: rs_230.jpg
# Imagem movida: rs_232.jpg
# Imagem movida: rs_234.jpg
# Imagem movida: rs_235.jpg
# Imagem movida: rs_236.jpg
# Imagem movida: rs_237.jpg
# Imagem movida: rs_238.jpg
# Imagem movida: rs_24.jpg
# Imagem movida: rs_241.jpg
# Imagem movida: rs_245.jpg
# Imagem movida: rs_247.jpg
# Imagem movida: rs_248.jpg
# Imagem movida: rs_249.jpg
# Imagem movida: rs_25.jpg
# Imagem movida: rs_250.jpg
# Imagem movida: rs_252.jpg
# Imagem movida: rs_253.jpg
# Imagem movida: rs_255.jpg
# Imagem movida: rs_256.jpg
# Imagem movida: rs_259.jpg
# Imagem movida: rs_26.jpg
# Imagem movida: rs_260.jpg
# Imagem movida: rs_261.jpg
# Imagem movida: rs_262.jpg
# Imagem movida: rs_264.jpg
# Imagem movida: rs_265.jpg
# Imagem movida: rs_266.jpg
# Imagem movida: rs_267.jpg
# Imagem movida: rs_268.jpg
# Imagem movida: rs_269.jpg
# Imagem movida: rs_27.jpg
# Imagem movida: rs_271.jpg
# Imagem movida: rs_272.jpg
# Imagem movida: rs_273.jpg
# Imagem movida: rs_278.jpg
# Imagem movida: rs_279.jpg
# Imagem movida: rs_280.jpg
# Imagem movida: rs_281.jpg
# Imagem movida: rs_282.jpg
# Imagem movida: rs_283.jpg
# Imagem movida: rs_284.jpg
# Imagem movida: rs_285.jpg
# Imagem movida: rs_286.jpg
# Imagem movida: rs_288.jpg
# Imagem movida: rs_289.jpg
# Imagem movida: rs_29.jpg
# Imagem movida: rs_290.jpg
# Imagem movida: rs_291.jpg
# Imagem movida: rs_292.jpg
# Imagem movida: rs_293.jpg
# Imagem movida: rs_297.jpg
# Imagem movida: rs_299.jpg
# Imagem movida: rs_3.jpg
# Imagem movida: rs_30.jpg
# Imagem movida: rs_300.jpg
# Imagem movida: rs_301.jpg
# Imagem movida: rs_303.jpg
# Imagem movida: rs_304.jpg
# Imagem movida: rs_305.jpg
# Imagem movida: rs_307.jpg
# Imagem movida: rs_309.jpg
# Imagem movida: rs_31.jpg
# Imagem movida: rs_310.jpg
# Imagem movida: rs_311.jpg
# Imagem movida: rs_312.jpg
# Imagem movida: rs_315.jpg
# Imagem movida: rs_316.jpg
# Imagem movida: rs_317.jpg
# Imagem movida: rs_318.jpg
# Imagem movida: rs_319.jpg
# Imagem movida: rs_32.jpg
# Imagem movida: rs_320.jpg
# Imagem movida: rs_321.jpg
# Imagem movida: rs_322.jpg
# Imagem movida: rs_33.jpg
# Imagem movida: rs_34.jpg
# Imagem movida: rs_35.jpg
# Imagem movida: rs_36.jpg
# Imagem movida: rs_37.jpg
# Imagem movida: rs_38.jpg
# Imagem movida: rs_39.jpg
# Imagem movida: rs_4.jpg
# Imagem movida: rs_40.jpg
# Imagem movida: rs_41.jpg
# Imagem movida: rs_42.jpg
# Imagem movida: rs_43.jpg
# Imagem movida: rs_44.jpg
# Imagem movida: rs_45.jpg
# Imagem movida: rs_46.jpg
# Imagem movida: rs_48.jpg
# Imagem movida: rs_49.jpg
# Imagem movida: rs_5.jpg
# Imagem movida: rs_50.jpg
# Imagem movida: rs_52.jpg
# Imagem movida: rs_53.jpg
# Imagem movida: rs_54.jpg
# Imagem movida: rs_55.jpg
# Imagem movida: rs_57.jpg
# Imagem movida: rs_58.jpg
# Imagem movida: rs_59.jpg
# Imagem movida: rs_6.jpg
# Imagem movida: rs_60.jpg
# Imagem movida: rs_61.jpg
# Imagem movida: rs_62.jpg
# Imagem movida: rs_63.jpg
# Imagem movida: rs_64.jpg
# Imagem movida: rs_68.jpg
# Imagem movida: rs_7.jpg
# Imagem movida: rs_70.jpg
# Imagem movida: rs_71.jpg
# Imagem movida: rs_72.jpg
# Imagem movida: rs_73.jpg
# Imagem movida: rs_75.jpg
# Imagem movida: rs_76.jpg
# Imagem movida: rs_78.jpg
# Imagem movida: rs_8.jpg
# Imagem movida: rs_80.jpg
# Imagem movida: rs_81.jpg
# Imagem movida: rs_83.jpg
# Imagem movida: rs_84.jpg
# Imagem movida: rs_85.jpg
# Imagem movida: rs_86.jpg
# Imagem movida: rs_87.jpg
# Imagem movida: rs_88.jpg
# Imagem movida: rs_89.jpg
# Imagem movida: rs_92.jpg
# Imagem movida: rs_93.jpg
# Imagem movida: rs_94.jpg
# Imagem movida: rs_95.jpg
# Imagem movida: rs_96.jpg
# Imagem movida: rs_97.jpg
# Imagem movida: rs_98.jpg
# Imagem movida: rs_99.jpg
# Undersampling concluído para a pasta c:\Users\rdalm\OneDrive\Área de Trabalho\esw-pin3-projeto\esw-pin3-projeto\modelo_2\imagens\roma.
# Contagem de imagens de morango rebalanceado: 250
# Contagem de imagens de pêssego rebalanceado: 250
# Contagem de imagens de romã rebalanceado: 250

# %%
## 2. Definição e separação dos dados de treinamento e dados de teste
projeto_dir = os.getcwd() 
dataset_treinamento_dir = os.path.join(projeto_dir, 'imagens_treinamento') 
dataset_teste_dir = os.path.join(projeto_dir, 'imagens_teste') 

proporcao_dataset_treinamento = 0.7 # 70% será utilizado no treinamento
proporcao_dataset_teste = 1 - proporcao_dataset_treinamento # 30% será utilizado no teste
random_seed = 42 

classes = ['morango_rebalanceado', 'pessego_rebalanceado', 'roma_rebalanceado']

def split_dataset_to_train_and_test(classe):
    dataset_treinamento_classe_dir = os.path.join(dataset_treinamento_dir, classe) 
    dataset_teste_classe_dir = os.path.join(dataset_teste_dir, classe) 

    dataset_classe_dir = os.path.join(projeto_dir, 'imagens', classe)
    imagens_classe = [os.path.join(dataset_classe_dir, img) for img in os.listdir(dataset_classe_dir)]

    imagens_treinamento_classe, imagens_teste_classe = train_test_split(imagens_classe, test_size=proporcao_dataset_teste, random_state=random_seed) 

    os.makedirs(dataset_treinamento_classe_dir, exist_ok=True)
    os.makedirs(dataset_teste_classe_dir, exist_ok=True)
    
    for imagem in imagens_treinamento_classe:
        shutil.copy(imagem, dataset_treinamento_classe_dir) 

    for imagem in imagens_teste_classe:
        shutil.copy(imagem, dataset_teste_classe_dir) 

# Verifica se os diretórios de treinamento e teste já existem
if not os.path.exists(dataset_treinamento_dir) or not os.path.exists(dataset_teste_dir):
    # Cria os diretórios de treinamento e teste
    os.makedirs(dataset_treinamento_dir, exist_ok=True)
    os.makedirs(dataset_teste_dir, exist_ok=True)

    for classe in classes:
        split_dataset_to_train_and_test(classe)

# %%
## 3. Como ficou dataset de treinamento e de testes:

dataset_treinamento_morango_len = len(os.listdir(os.path.join(dataset_treinamento_dir, 'morango_rebalanceado')))
dataset_teste_morango_len = len(os.listdir(os.path.join(dataset_teste_dir, 'morango_rebalanceado')))
dataset_treinamento_pessego_len = len(os.listdir(os.path.join(dataset_treinamento_dir, 'pessego_rebalanceado')))
dataset_teste_pessego_len = len(os.listdir(os.path.join(dataset_teste_dir, 'pessego_rebalanceado')))
dataset_treinamento_roma_len = len(os.listdir(os.path.join(dataset_treinamento_dir, 'roma_rebalanceado')))
dataset_teste_roma_len = len(os.listdir(os.path.join(dataset_teste_dir, 'roma_rebalanceado')))

print(f'Contagem de imagens de morango para treinamento: {dataset_treinamento_morango_len}')
print(f'Contagem de imagens de morango para teste: {dataset_teste_morango_len}')
print(f'Contagem de imagens de pêssego para treinamento: {dataset_treinamento_pessego_len}')
print(f'Contagem de imagens de pêssego para teste: {dataset_teste_pessego_len}')
print(f'Contagem de imagens de romã para treinamento: {dataset_treinamento_roma_len}')
print(f'Contagem de imagens de romã para teste: {dataset_teste_roma_len}')
# Out:
# Contagem de imagens de morango para treinamento: 174
# Contagem de imagens de morango para teste: 76
# Contagem de imagens de pêssego para treinamento: 174
# Contagem de imagens de pêssego para teste: 76
# Contagem de imagens de romã para treinamento: 174
# Contagem de imagens de romã para teste: 76

# %%
## 4. Pré-processamento das imagens
import os
import numpy as np
import tensorflow as tf

input_shape = (300, 300, 3)

def carregar_dados_do_diretorio(directory, label_mode='categorical', batch_size=32):
    data = []
    labels = []
    class_names = sorted(os.listdir(directory))
    
    class_to_index = {class_name: i for i, class_name in enumerate(class_names)}
    
    for class_name in class_names:
        class_dir = os.path.join(directory, class_name)
        for image_file in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_file)
            image = tf.keras.preprocessing.image.load_img(image_path, target_size=(300, 300))
            image_array = tf.keras.preprocessing.image.img_to_array(image)
            data.append(image_array)
            labels.append(class_to_index[class_name])
    
    if label_mode == 'categorical':
        labels = tf.keras.utils.to_categorical(labels)
    
    dataset = tf.data.Dataset.from_tensor_slices((data, labels))
    dataset = dataset.batch(batch_size)
    
    return dataset

data_set_treinamento = carregar_dados_do_diretorio(dataset_treinamento_dir)
data_set_teste = carregar_dados_do_diretorio(dataset_teste_dir)

# %%
## 5. Definição da arquitetura da rede neural do modelo
import tensorflow as tf

base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

# Congela as camadas do modelo base para que não sejam treinadas novamente
base_model.trainable = False

# Adiciona camadas personalizadas ao final da ResNet50
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Input(shape=(300,300,3)))
model.add(base_model)
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(3, activation='softmax')) 

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\rdalm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\rdalm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From c:\Users\rdalm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 24113027 (91.98 MB)
# Trainable params: 525315 (2.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
## 6. Treinamento do Modelo

# Treina apenas as camadas adicionadas (as últimas camadas) do modelo
history = model.fit(
    data_set_treinamento, 
    epochs=10,  
    batch_size=32  
)

loss, accuracy = model.evaluate(data_set_teste)

model_dir = 'modelo'
os.makedirs(model_dir, exist_ok=True)
model_path = os.path.join(model_dir, 'modelo2.keras')
model.save(model_path)

print("Modelo treinado salvo em:", model_path)
# Out:
# 8/8 [==============================] - 13s 2s/step - loss: 0.0434 - accuracy: 0.9912
# Modelo treinado salvo em: modelo\modelo2.keras

# %%
## 7. Avaliação com F1 Score

import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score

input_shape = (300, 300, 3)

# Função para pré-processar
def preprocess_dataset(directory, target_size=(300, 300), label_mode='categorical', batch_size=32):
    data = []
    labels = []
    class_names = sorted(os.listdir(directory))

    class_to_index = {class_name: i for i, class_name in enumerate(class_names)}
    
    for class_name in class_names:
        class_dir = os.path.join(directory, class_name)
        for image_file in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_file)
            image = tf.keras.preprocessing.image.load_img(image_path, target_size=target_size)
            image_array = tf.keras.preprocessing.image.img_to_array(image)
            data.append(image_array)
            labels.append(class_to_index[class_name])
    
    if label_mode == 'categorical':
        labels = tf.keras.utils.to_categorical(labels)
    
    dataset = tf.data.Dataset.from_tensor_slices((data, labels))
    dataset = dataset.batch(batch_size)
    
    return dataset

dataset_treinamento_dir = os.path.join(os.getcwd(), 'imagens_treinamento')
dataset_teste_dir = os.path.join(os.getcwd(), 'imagens_teste')

data_set_treinamento = preprocess_dataset(dataset_treinamento_dir)
data_set_teste = preprocess_dataset(dataset_teste_dir)

model_path = os.path.join(os.getcwd(), 'modelo', 'modelo2.keras')
model = tf.keras.models.load_model(model_path)

y_pred = model.predict(data_set_teste)
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = []
for images, labels in data_set_teste:
    y_true.extend(np.argmax(labels, axis=1))

f1 = f1_score(y_true, y_pred_classes, average='weighted')

print("F1 Score:", f1)
# Out:
# 8/8 [==============================] - 18s 2s/step
# F1 Score: 0.9912280701754386

# %%
## Teste

import tensorflow as tf
import numpy as np
import os

def preprocess_image(image_path, target_size=(300, 300)):
    image = tf.keras.preprocessing.image.load_img(image_path, target_size=target_size)
    image_array = tf.keras.preprocessing.image.img_to_array(image)
    image_array = np.expand_dims(image_array, axis=0)
    return image_array

dataset_treinamento_dir = os.getcwd() + '/imagens_treinamento'

class_names = sorted(os.listdir(dataset_treinamento_dir))

image_path = os.getcwd() + '/imagens_teste/roma_rebalanceado/rs_18.jpg'

processed_image = preprocess_image(image_path)

model = tf.keras.models.load_model(os.getcwd() + '/modelo/modelo2.keras')

predictions = model.predict(processed_image)

predicted_class_index = np.argmax(predictions, axis=1)

# Mapeia o índice da classe de volta para o nome da classe
predicted_class_name = class_names[predicted_class_index[0]]

print(f'A imagem pertence à classe: {predicted_class_name}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# A imagem pertence à classe: roma_rebalanceado
